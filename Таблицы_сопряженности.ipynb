# %% [markdown]
# <a href="https://colab.research.google.com/github/Almodovare/Notebooks/blob/main/%D0%A2%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D1%8B_%D1%81%D0%BE%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 27.5 MB/s eta 0:00:00
# ...

# %%
import pyreadstat
import pandas as pd
from scipy.stats import chi2_contingency

# %%
df_1 = pd.read_spss('/content/База_ДНК (08.04).sav')
df_1
# Out:
#                     ID      SEX   AGE                                   FO  \
# 0     0afeda8dfe8ce1bc  Мужской  53.0  Северо-Кавказский федеральный округ
# 1     0afec438540ce727  Мужской  72.0        Приволжский федеральный округ
# 2     0afec0aff0cce79d  Женский  60.0        Приволжский федеральный округ
# 3     0afed315418cefb3  Мужской  59.0        Приволжский федеральный округ
# 4     0afece9f650ce912  Женский  72.0        Приволжский федеральный округ
# ...                ...      ...   ...                                  ...
# 1603  0afecb1c284ce377  Женский  41.0        Приволжский федеральный округ
# 1604  0afefcfe11cce19f  Женский  41.0        Центральный федеральный округ
# 1605  0afecadf074ce250  Женский  45.0        Приволжский федеральный округ
# 1606  0afec64c8e8ce1da  Женский  67.0        Приволжский федеральный округ
# 1607  0afec7d8cc8ce71a  Женский  62.0        Приволжский федеральный округ
#
#                                                     TIP  \
# ...

# %%
df, meta = pyreadstat.read_sav("/content/База_ДНК (08.04).sav")

# %%
df
# Out:
#                     ID  SEX   AGE   FO  TIP  dnk1  dnk1_1d  dnk1_2d  dnk2  \
# 0     0afeda8dfe8ce1bc  1.0  53.0  4.0  3.0   1.0      5.0      NaN   1.0
# 1     0afec438540ce727  1.0  72.0  5.0  7.0   2.0      NaN     13.0   1.0
# 2     0afec0aff0cce79d  2.0  60.0  5.0  3.0   1.0      4.0      NaN  99.0
# 3     0afed315418cefb3  1.0  59.0  5.0  1.0  99.0      NaN      NaN   3.0
# 4     0afece9f650ce912  2.0  72.0  5.0  4.0   1.0      1.0      NaN   3.0
# ...                ...  ...   ...  ...  ...   ...      ...      ...   ...
# 1603  0afecb1c284ce377  2.0  41.0  5.0  7.0  99.0      NaN      NaN   3.0
# 1604  0afefcfe11cce19f  2.0  41.0  1.0  3.0  99.0      NaN      NaN  99.0
# 1605  0afecadf074ce250  2.0  45.0  5.0  7.0   2.0      NaN      9.0   2.0
# 1606  0afec64c8e8ce1da  2.0  67.0  5.0  7.0   3.0      NaN      NaN  99.0
# 1607  0afec7d8cc8ce71a  2.0  62.0  5.0  7.0   1.0     16.0      NaN   1.0
#
#       dnk3  ...  DETI_1  DETI_2  DETI_3  DETI_4  DETI_5  DETI_6  PROF1  PROF2  \
# ...

# %%
meta
# Out:
# metadata_container(column_names=['ID', 'SEX', 'AGE', 'FO', 'TIP', 'dnk1', 'dnk1_1d', 'dnk1_2d', 'dnk2', 'dnk3', 'dnk4', 'TV', 'd1', 'EDU', 'DOHOD_0', 'DETI_1', 'DETI_2', 'DETI_3', 'DETI_4', 'DETI_5', 'DETI_6', 'PROF1', 'PROF2', 'PROF3', 'weight1'], column_labels=['Идентификатор респондента', 'Пол', 'Сколько полных лет Вам исполнилось?', 'Федеральный округ', 'Тип населенного пункта', 'dnk1. Сменим тему. В России предложили ввести обязательную процедуру ДНК-тестирования в родильных домах с согласия обоих родителей. По мнению авторов, нововведение обеспечит правовую защиту детей с первых дней жизни, например, облегчит назначение выпла', 'Скорее положительно (поясните, почему?)', 'Скорее отрицательно (поясните, почему?)', 'dnk2. Как Вы считаете, если ДНК-тест подтверждает отцовство, факт его проведения будет скорее…?', 'dnk3. А Вы согласились бы на проведение такого теста при рождении ребенка или нет?', 'dnk4. Представьте, что мужчина узнаёт, что ребенок, которого он воспитывал, не являе
# ...

# %%
meta.column_labels # выводит метки переменных
# Out:
# ['Идентификатор респондента',
#  'Пол',
#  'Сколько полных лет Вам исполнилось?',
#  'Федеральный округ',
#  'Тип населенного пункта',
#  'dnk1. Сменим тему. В России предложили ввести обязательную процедуру ДНК-тестирования в родильных домах с согласия обоих родителей. По мнению авторов, нововведение обеспечит правовую защиту детей с первых дней жизни, например, облегчит назначение выпла',
#  'Скорее положительно (поясните, почему?)',
#  'Скорее отрицательно (поясните, почему?)',
#  'dnk2. Как Вы считаете, если ДНК-тест подтверждает отцовство, факт его проведения будет скорее…?',
#  'dnk3. А Вы согласились бы на проведение такого теста при рождении ребенка или нет?',
#  'dnk4. Представьте, что мужчина узнаёт, что ребенок, которого он воспитывал, не является его биологическим. Как, по Вашему мнению, ему следует поступить?',
#  'TV. Поговорим немного о Вас. Скажите, пожалуйста, Вы смотрите телевизор или нет? Если смотрите, то как часто?',
# ...

# %%
meta.column_names # выводит имена переменных
# Out:
# ['ID',
#  'SEX',
#  'AGE',
#  'FO',
#  'TIP',
#  'dnk1',
#  'dnk1_1d',
#  'dnk1_2d',
#  'dnk2',
#  'dnk3',
#  'dnk4',
#  'TV',
#  'd1',
#  'EDU',
#  'DOHOD_0',
#  'DETI_1',
#  'DETI_2',
#  'DETI_3',
#  'DETI_4',
#  'DETI_5',
#  'DETI_6',
#  'PROF1',
#  'PROF2',
#  'PROF3',
#  'weight1']

# %%
meta.value_labels # выводит значения переменных
# Out:
# {'labels0': {1.0: 'Мужской', 2.0: 'Женский'},
#  'labels1': {1.0: 'Центральный федеральный округ',
#   2.0: 'Северо-Западный федеральный округ',
#   3.0: 'Южный федеральный округ',
#   4.0: 'Северо-Кавказский федеральный округ',
#   5.0: 'Приволжский федеральный округ',
#   6.0: 'Уральский федеральный округ',
#   7.0: 'Сибирский федеральный округ',
#   8.0: 'Дальневосточный федеральный округ'},
#  'labels2': {1.0: 'Город с численностью жителей миллион и более человек',
#   2.0: 'Город с численностью от 500 тысяч до 950 тысяч',
#   3.0: 'Город с численностью от 100 тысяч до 500 тысяч',
#   4.0: 'Город с численностью от 50 тысяч до 100 тысяч',
#   5.0: 'Город с численностью менее 50 тысяч',
#   6.0: 'Поселок городского типа',
#   7.0: 'Село'},
#  'labels3': {1.0: 'Скорее положительно (поясните, почему?)',
#   2.0: 'Скорее отрицательно (поясните, почему?)',
#   3.0: 'Скорее безразлично',
#   99.0: 'Затрудняюсь ответить',
# ...

# %%
meta.variable_measure # выводит тип шкалы
# Out:
# {'ID': 'nominal',
#  'SEX': 'nominal',
#  'AGE': 'nominal',
#  'FO': 'nominal',
#  'TIP': 'nominal',
#  'dnk1': 'nominal',
#  'dnk1_1d': 'nominal',
#  'dnk1_2d': 'nominal',
#  'dnk2': 'nominal',
#  'dnk3': 'nominal',
#  'dnk4': 'nominal',
#  'TV': 'nominal',
#  'd1': 'nominal',
#  'EDU': 'nominal',
#  'DOHOD_0': 'nominal',
#  'DETI_1': 'nominal',
#  'DETI_2': 'nominal',
#  'DETI_3': 'nominal',
#  'DETI_4': 'nominal',
#  'DETI_5': 'nominal',
#  'DETI_6': 'nominal',
#  'PROF1': 'nominal',
#  'PROF2': 'nominal',
#  'PROF3': 'nominal',
#  'weight1': 'nominal'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1608 entries, 0 to 1607
# Data columns (total 25 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       1608 non-null   object
#  1   SEX      1608 non-null   float64
#  2   AGE      1608 non-null   float64
#  3   FO       1608 non-null   float64
#  4   TIP      1608 non-null   float64
#  5   dnk1     1608 non-null   float64
#  6   dnk1_1d  838 non-null    float64
#  7   dnk1_2d  275 non-null    float64
#  8   dnk2     1608 non-null   float64
#  9   dnk3     1608 non-null   float64
#  10  dnk4     1608 non-null   float64
#  11  TV       1608 non-null   float64
#  12  d1       1608 non-null   float64
#  13  EDU      1608 non-null   float64
#  14  DOHOD_0  1608 non-null   float64
#  15  DETI_1   1608 non-null   float64
#  16  DETI_2   240 non-null    float64
#  17  DETI_3   16 non-null     float64
#  18  DETI_4   0 non-null      float64
#  19  DETI_5   0 non-null      float64
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1608 entries, 0 to 1607
# Data columns (total 25 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       1608 non-null   object
#  1   SEX      1608 non-null   category
#  2   AGE      1608 non-null   float64
#  3   FO       1608 non-null   category
#  4   TIP      1608 non-null   category
#  5   dnk1     1608 non-null   category
#  6   dnk1_1d  838 non-null    category
#  7   dnk1_2d  275 non-null    category
#  8   dnk2     1608 non-null   category
#  9   dnk3     1608 non-null   category
#  10  dnk4     1608 non-null   category
#  11  TV       1608 non-null   category
#  12  d1       1608 non-null   category
#  13  EDU      1608 non-null   category
#  14  DOHOD_0  1608 non-null   category
#  15  DETI_1   1608 non-null   category
#  16  DETI_2   240 non-null    category
#  17  DETI_3   16 non-null     category
#  18  DETI_4   0 non-null      category
# ...

# %%
df['dnk1'].unique()
# Out:
# array([ 1.,  2., 99.,  3.])

# %%
df['dnk1'].value_counts().sort_index() #
# Out:
# dnk1
# 1.0     840
# 2.0     277
# 3.0     380
# 99.0    111
# Name: count, dtype: int64

# %%
df['dnk1'].value_counts().sort_values() #
# Out:
# dnk1
# 99.0    111
# 2.0     277
# 3.0     380
# 1.0     840
# Name: count, dtype: int64

# %%
df_1['dnk1'].value_counts()
# Out:
# dnk1
# Скорее положительно (поясните, почему?)    840
# Скорее безразлично                         380
# Скорее отрицательно (поясните, почему?)    277
# Затрудняюсь ответить                       111
# Name: count, dtype: int64

# %%
df_1['dnk1'].value_counts(normalize = True).round(2)*100
# Out:
# dnk1
# Скорее положительно (поясните, почему?)    52.0
# Скорее безразлично                         24.0
# Скорее отрицательно (поясните, почему?)    17.0
# Затрудняюсь ответить                        7.0
# Name: proportion, dtype: float64

# %%
df_1['dnk1_1d'].unique()
# Out:
# ['Для защиты ребенка и матери / безопасность', NaN, 'Во избежание спорных моментов / юридические в..., 'Бывает путают детей в роддамах / меняют', 'Снимет кучу вопросов', ..., 'Дети будут знать кто их родители', 'Другое', 'Защита прав отцов', 'Получение социальных выплат', 'Затрудняюсь ответить']
# Length: 23
# Categories (22, object): ['Больше уверенности / доверия / если нечего ск..., 'Бывает путают детей в роддамах / меняют',
#                           'Бывают разные ситуации', 'В медицинских целях / выявление генетических ..., ...,
#                           'Поможет в установлении личности', 'Предотвратить измены / сохранение семей',
#                           'Родители будут знать, что это их ребенок', 'Снимет кучу вопросов']

# %%
df_1['dnk1_1d'].value_counts()
# Out:
# dnk1_1d
# Определение отцовства / отец будет знать его ребенок или нет / знать, кто родитель / от кого ребенок    132
# Есть случаи, когда отцы воспитывают не своих детей / женщины гуляют, обманывают                          75
# Положительно отношусь / это правильно / полезно                                                          75
# Во избежание спорных моментов / юридические вопросы                                                      69
# Бывает путают детей в роддамах / меняют                                                                  62
# Больше уверенности / доверия / если нечего скрывать / не будет сомнений                                  59
# Меньше обмана / проблем                                                                                  53
# Для защиты ребенка и матери / безопасность                                                               43
# Отцы должны принимать участие в жизни ребенка                                                            30
# ...

# %%
cros_1 = pd.crosstab (df_1['SEX'], df_1['dnk1'], margins=True)

# %%
pd.crosstab(df_1['SEX'], df_1['dnk1'], margins=True, normalize= True).round(3)*100
# Out:
# dnk1     Затрудняюсь ответить  Скорее безразлично  \
# SEX
# Женский                   3.0                10.9
# Мужской                   3.9                12.7
# All                       6.9                23.6
#
# dnk1     Скорее отрицательно (поясните, почему?)  \
# SEX
# Женский                                      7.8
# Мужской                                      9.4
# All                                         17.2
#
# dnk1     Скорее положительно (поясните, почему?)    All
# SEX
# Женский                                     19.0   40.8
# Мужской                                     33.2   59.2
# All                                         52.2  100.0

# %%
chi2_contingency(cros_1) # тест на значимость различий хи-квадрат Пирсона
# Out:
# Chi2ContingencyResult(statistic=np.float64(14.02050228560343), pvalue=np.float64(0.08123259451042934), dof=8, expected_freq=array([[  45.28358209,  155.02487562,  113.00497512,  342.68656716,
#          656.        ],
#        [  65.71641791,  224.97512438,  163.99502488,  497.31343284,
#          952.        ],
#        [ 111.        ,  380.        ,  277.        ,  840.        ,
#         1608.        ]]))
